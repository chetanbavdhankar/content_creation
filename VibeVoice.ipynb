# %%
Use venv "venv_vibe"

# %%
# https://github.com/vibevoice-community/VibeVoice?tab=readme-ov-file
python demo/gradio_demo.py --model_path vibevoice/VibeVoice-1.5B --device cuda

# %%
# Free Voice Sample Sources:
# 1. Voice Acting & Sample Sites

# Voices.com - Professional voice actor demos (https://www.voices.com/voice-actors)
# Voice123.com - Voice actor portfolios with samples
# Fiverr Voice Over - Browse voice actor profiles with demo reels

# 2. YouTube

# Search for: "voice actor demo reel"
# Audiobook narrators' channels
# Podcast introductions
# Voice impression compilations
# Tip: Use a YouTube downloader to get audio, then extract/trim the voice portion

# 3. Public Domain Audio

# LibriVox (https://librivox.org/) - Free public domain audiobooks
# Internet Archive (https://archive.org/details/audio) - Historical recordings
# Wikimedia Commons - Public domain voice recordings

# 4. Podcast Clips

# Find podcasts with interesting voices
# Extract short clips (5-15 seconds of clean speech)

# 5. Free Sound Libraries

# Freesound.org - User-uploaded voice samples
# BBC Sound Effects - Some voice samples available
